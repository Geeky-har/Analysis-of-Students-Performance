# %% [markdown]
# # Notebook to analyse the students performance on the basis of Internal-I

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('internal1.csv', index_col=0)

# %%
df
# Out:
#                 OFFICE MANAGEMENT LOGICAL ORGANISATION C LANGUAGE  \
# NAME
# TEJAS                           *                   31         37
# KAPIL MANDAL                   31                   37         22
# NIKHIL                         34                   26         12
# RUPAM                          45                   41         40
# HARSH                          40                   38         34
# MONICA AGGARWAL                43                   42         34
# AYUSH SINGH                    12                   AB         AB
# ANKIT TIWARI                   AB                   15          7
# ANJALI                         13                   19         20
# VISHAL KUMAR                   25                   39         19
# ROHAN                          15                    0         AB
# KUNAL SAINI                    10                   19         12
# SIMRAN JHA                     17                   26         AB
# ...

# %%
df.columns
# Out:
# Index(['OFFICE MANAGEMENT', 'LOGICAL ORGANISATION', 'C LANGUAGE',
#        'COMPUTER FUNDAMENTALS', 'MATHS'],
#       dtype='object')

# %%
df.index
# Out:
# Index(['TEJAS', 'KAPIL MANDAL', 'NIKHIL', 'RUPAM', 'HARSH', 'MONICA AGGARWAL',
#        'AYUSH SINGH', 'ANKIT TIWARI', 'ANJALI', 'VISHAL KUMAR', 'ROHAN',
#        'KUNAL SAINI ', 'SIMRAN JHA', 'RIYA', 'SHIVAM BANSAL', 'KUNDAN',
#        'RIYAZ', 'YOGESH', 'MOHIT GARG', 'ABHISHEK ANAND', 'SHYAMSUNDAR',
#        'SHUBHAM GAUR', 'SHUBHAM SINGH', 'VIKAS K PANDEY', 'SUNIL', 'POONAM',
#        'VISHAL PANDEY', 'BITTU', 'VISHWAJEET', 'ARYAMAN RANA'],
#       dtype='object', name='NAME')

# %%
harsh = np.array(df.loc['HARSH', :])

# %%
harsh
# Out:
# array(['40', '38', '34', 49, '40'], dtype=object)

# %%
df.replace(to_replace='AB',
          value=0, inplace=True)

# %%
df.replace(to_replace='*',
          value=0, inplace=True)

# %%
df
# Out:
#                 OFFICE MANAGEMENT LOGICAL ORGANISATION C LANGUAGE  \
# NAME
# TEJAS                           0                   31         37
# KAPIL MANDAL                   31                   37         22
# NIKHIL                         34                   26         12
# RUPAM                          45                   41         40
# HARSH                          40                   38         34
# MONICA AGGARWAL                43                   42         34
# AYUSH SINGH                    12                    0          0
# ANKIT TIWARI                    0                   15          7
# ANJALI                         13                   19         20
# VISHAL KUMAR                   25                   39         19
# ROHAN                          15                    0          0
# KUNAL SAINI                    10                   19         12
# SIMRAN JHA                     17                   26          0
# ...

# %%
df.iloc[[0], :]
# Out:
#       OFFICE MANAGEMENT LOGICAL ORGANISATION C LANGUAGE  \
# NAME
# TEJAS                 0                   31         37
#
#        COMPUTER FUNDAMENTALS MATHS
# NAME
# TEJAS                     28    15

# %% [markdown]
# # Office Management Tools

# %%
max_score=df[df[['OFFICE MANAGEMENT']].apply(lambda x: x[0].isdigit(), axis=1)].max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-4741929e2afa> in <module>
# ----> 1 max_score=df[df[['OFFICE MANAGEMENT']].apply(lambda x: x[0].isdigit(), axis=1)].max()
#
# c:\users\harsh\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7543             kwds=kwds,
#    7544         )
# -> 7545         return op.get_result()
#    7546
#    7547     def applymap(self, func) -> "DataFrame":
#
# c:\users\harsh\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ...

# %%
df.sort_values('C LANGUAGE', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-1d854e57a4aa> in <module>
# ----> 1 df.sort_values('C LANGUAGE', ascending=False)
#
# c:\users\harsh\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5299
#    5300             indexer = nargsort(
# -> 5301                 k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    5302             )
#    5303
#
# c:\users\harsh\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\sorting.py in nargsort(items, kind, ascending, na_position, key)
#     306         non_nans = non_nans[::-1]
#     307         non_nan_idx = non_nan_idx[::-1]
# --> 308     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     309     if not ascending:
# ...

# %%
df

# %%
max_score_omt = max_score['OFFICE MANAGEMENT']

# %%
name_omt_max = df[df['OFFICE MANAGEMENT'] == max_score_omt].index.values

# %%
name_omt_max

# %%
min_score=df[df[['OFFICE MANAGEMENT']].apply(lambda x: x[0].isdigit(), axis=1)].min()

# %%
min_score

# %%
min_score_omt = min_score['OFFICE MANAGEMENT']

# %%
min_score_omt

# %%
name_omt_min = df[df['OFFICE MANAGEMENT'] == min_score_omt].index.values

# %%
name_omt_min

# %%
lst = df.loc[:, 'OFFICE MANAGEMENT']
lst.index

# %%
present_count_omt = 0
absent_count_omt = 0
pass_count_omt = 0
fail_count_omt = 0

for i in lst:
    try:
        if pd.to_numeric(i) >= 16.5:
            pass_count_omt += 1
        
    except Exception as e:
        fail_count_omt += 1
    
    if i == '*' or i == 'AB':
        absent_count_omt += 1
        
    else:
        present_count_omt += 1
        flst.append(i)
        
fail_count_omt = len(df.index) - pass_count_omt

# %% [markdown]
# *Pie chart visualisation for present/absent ratios*

# %%
labels = 'Present', 'Absent/Not Found'
sizes = [present_count_omt, absent_count_omt]
explode = [0, 0.1]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# *Pie chart visualisation for pass/fail ratios*

# %%
labels = 'Pass', 'Fail'
sizes = [pass_count_omt, fail_count_omt]
explode = [0, 0.1]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
newdf = df.sort_values('OFFICE MANAGEMENT', ascending=False)

# %%
newdf.describe().index
